# %% [markdown]
# Write a program that creates gramatically valid English sentences.
# Here, we consider a sentence to be gramatically correct when it follows the simple English grammar of the form: Article Adjective Noun Verb. That is, even the sentence A insect fly. is, for the moment, considered correct.
# Create additionally to the exercise above, a list of definite and indefinite articles and verbs from an online resource.
# https://www.espressoenglish.net/100-most-common-english-verbs/
# https://www.espressoenglish.net/100-common-nouns-in-english/
# https://www.espressoenglish.net/100-common-adjectives-in-english/

# %%
verbs = ["be","have","do","say","go"]
nouns = ["time", "year", "people", "way", "day"]
adjectivs = ["other","new","good","high","old"]

for verb in verbs:
    for adjectiv in adjectivs:    
        for noun in nouns:
            print(adjectiv + " " + noun + " " + verb)
    

printlist = [(adj, noun, verb) for adj in adjectivs for noun in nouns for verb in verbs]
# Out:
# other time be
# other year be
# other people be
# other way be
# other day be
# new time be
# new year be
# new people be
# new way be
# new day be
# good time be
# good year be
# good people be
# good way be
# good day be
# high time be
# high year be
# high people be
# high way be
# high day be
# old time be
# old year be
# old people be
# old way be
# old day be
# other time have
# other year have
# other people have
# other way have
# other day have
# new time have
# new year have
# new people have
# new way have
# new day have
# good time have
# good year have
# good people have
# good way have
# good day have
# high time have
# high year have
# high people have
# high way have
# high day have
# old time have
# old year have
# old people have
# old way have
# old day have
# other time do
# other year do
# other people do
# other way do
# other day do
# new time do
# new year do
# new people do
# new way do
# new day do
# good time do
# good year do
# good people do
# good way do
# good day do
# high time do
# high year do
# high people do
# high way do
# high day do
# old time do
# old year do
# old people do
# old way do
# old day do
# other time say
# other year say
# other people say
# other way say
# other day say
# new time say
# new year say
# new people say
# new way say
# new day say
# good time say
# good year say
# good people say
# good way say
# good day say
# high time say
# high year say
# high people say
# high way say
# high day say
# old time say
# old year say
# old people say
# old way say
# old day say
# other time go
# other year go
# other people go
# other way go
# other day go
# new time go
# new year go
# new people go
# new way go
# new day go
# good time go
# good year go
# good people go
# good way go
# good day go
# high time go
# high year go
# high people go
# high way go
# high day go
# old time go
# old year go
# old people go
# old way go
# old day go

# %% [markdown]
# Write a function that iterates through a list and prints each value without using a loop.
# That is, write a recursive function to print the values of a list.

# %%
def printWithoutLoop(myList):
    print(myList[len(myList)-1])
    myList.pop()
    if len(myList)>0 : printWithoutLoop(myList)
    

aList = ["heyyo", "howdy", "yoYO"]
printWithoutLoop(aList)
# Out:
# yoYO
# howdy
# heyyo
